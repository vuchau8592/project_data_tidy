# %%
import numpy as np
import pandas as pd
import requests
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("IDA_data1.csv")
df.head()
# Out:
# /home/vu/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   Project ID              Project Name  Original Principal Amount  \
# 0    P007353              EDUCATION II                  5000000.0
# 1    P009314    KHANABAD IRRIGATION II                 22000000.0
# 2    P009315  FRUIT & VEGETABLE EXPORT                 18000000.0
# 3    P005253  AMMAN WATER SUPP.SEW.III                 14000000.0
# 4    P002575                      PORT                 22000000.0
#
#    Cancelled Amount  Undisbursed Amount  Disbursed Amount  Repaid to IDA  \
# 0          24276.41                 0.0        4975723.59     4975723.59
# 1       21912427.15                 0.0          87572.85       87572.85
# 2       16914196.18                 0.0        1085803.82     1085803.82
# ...
